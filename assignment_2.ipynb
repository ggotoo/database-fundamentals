# %% [markdown]
# # Import Libraries

# %%
import requests, json
import pandas as pd
import sqlalchemy as sa

# %% [markdown]
# # Pull Dataset from API

# %% [markdown]
# We prepare a get request by first constructing th eapi url that we are going to query. We add a limit of 100000 (since the default is 100) and the resource id of the dataset. We also add headers to the request and then query the api.
#
# Since it is an Open Api there is no authentication required. Only the headers are required so that the api does not think we are a bot hitting the endpoint

# %%
resource_id='2925c1ea-8313-4e9b-bdea-344e521d2298'
Nrecords=100000
api_url = 'https://data.ontario.ca/api/3/action/datastore_search?resource_id={}&limit={}'.format(resource_id, Nrecords)

# %%
headers = {'user-agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 14_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/17.5 Safari/605.1.15'}

# %%
response = requests.get(api_url, headers=headers)
response.json()
# Out:
# {'help': 'https://data.ontario.ca/api/3/action/help_show?name=datastore_search',
#  'success': True,
#  'result': {'include_total': True,
#   'limit': 100000,
#   'records_format': 'objects',
#   'resource_id': '2925c1ea-8313-4e9b-bdea-344e521d2298',
#   'total_estimation_threshold': None,
#   'records': [{'_id': 1,
#     'Year/Année': '1940',
#     'Month/Mois': 'August/août',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 2,
#     'Year/Année': '1940',
#     'Month/Mois': 'October/octobre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 3,
#     'Year/Année': '1942',
#     'Month/Mois': 'November/novembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 4,
#     'Year/Année': '1944',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 5,
#     'Year/Année': '1944',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 6,
#     'Year/Année': '1945',
#     'Month/Mois': 'August/août',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 7,
#     'Year/Année': '1945',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 8,
#     'Year/Année': '1946',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 9,
#     'Year/Année': '1946',
#     'Month/Mois': 'November/novembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 10,
#     'Year/Année': '1946',
#     'Month/Mois': 'September/septembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 9},
#    {'_id': 11,
#     'Year/Année': '1947',
#     'Month/Mois': 'August/août',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 12,
#     'Year/Année': '1948',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 13,
#     'Year/Année': '1948',
#     'Month/Mois': 'July/juillet',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 14,
#     'Year/Année': '1949',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 15,
#     'Year/Année': '1949',
#     'Month/Mois': 'March/mars',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 16,
#     'Year/Année': '1949',
#     'Month/Mois': 'May/mai',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 8},
#    {'_id': 17,
#     'Year/Année': '1949',
#     'Month/Mois': 'December/décembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 9},
#    {'_id': 18,
#     'Year/Année': '1950',
#     'Month/Mois': 'February/février',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 19,
#     'Year/Année': '1950',
#     'Month/Mois': 'June/juin',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 8},
#    {'_id': 20,
#     'Year/Année': '1950',
#     'Month/Mois': 'November/novembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 8},
#    {'_id': 21,
#     'Year/Année': '1951',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 22,
#     'Year/Année': '1951',
#     'Month/Mois': 'February/février',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 23,
#     'Year/Année': '1951',
#     'Month/Mois': 'July/juillet',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 24,
#     'Year/Année': '1951',
#     'Month/Mois': 'November/novembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 25,
#     'Year/Année': '1951',
#     'Month/Mois': 'October/octobre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 26,
#     'Year/Année': '1951',
#     'Month/Mois': 'December/décembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 8},
#    {'_id': 27,
#     'Year/Année': '1951',
#     'Month/Mois': 'September/septembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 8},
#    {'_id': 28,
#     'Year/Année': '1952',
#     'Month/Mois': 'June/juin',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 29,
#     'Year/Année': '1952',
#     'Month/Mois': 'March/mars',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 30,
#     'Year/Année': '1952',
#     'Month/Mois': 'October/octobre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 31,
#     'Year/Année': '1952',
#     'Month/Mois': 'May/mai',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 12},
#    {'_id': 32,
#     'Year/Année': '1953',
#     'Month/Mois': 'November/novembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 33,
#     'Year/Année': '1953',
#     'Month/Mois': 'May/mai',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 34,
#     'Year/Année': '1954',
#     'Month/Mois': 'August/août',
#     'Municipality/Municipalité': 'HAMILTON',
#     'Totals / Totaux': 6},
#    {'_id': 35,
#     'Year/Année': '1954',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 36,
#     'Year/Année': '1954',
#     'Month/Mois': 'December/décembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 37,
#     'Year/Année': '1954',
#     'Month/Mois': 'June/juin',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 38,
#     'Year/Année': '1954',
#     'Month/Mois': 'March/mars',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 39,
#     'Year/Année': '1955',
#     'Month/Mois': 'June/juin',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 40,
#     'Year/Année': '1955',
#     'Month/Mois': 'November/novembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 41,
#     'Year/Année': '1956',
#     'Month/Mois': 'June/juin',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 42,
#     'Year/Année': '1956',
#     'Month/Mois': 'February/février',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 43,
#     'Year/Année': '1956',
#     'Month/Mois': 'July/juillet',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 8},
#    {'_id': 44,
#     'Year/Année': '1957',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 45,
#     'Year/Année': '1957',
#     'Month/Mois': 'December/décembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 46,
#     'Year/Année': '1957',
#     'Month/Mois': 'July/juillet',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 47,
#     'Year/Année': '1957',
#     'Month/Mois': 'October/octobre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 48,
#     'Year/Année': '1958',
#     'Month/Mois': 'July/juillet',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 49,
#     'Year/Année': '1958',
#     'Month/Mois': 'June/juin',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 50,
#     'Year/Année': '1958',
#     'Month/Mois': 'November/novembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 51,
#     'Year/Année': '1958',
#     'Month/Mois': 'September/septembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 8},
#    {'_id': 52,
#     'Year/Année': '1958',
#     'Month/Mois': 'February/février',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 9},
#    {'_id': 53,
#     'Year/Année': '1958',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 9},
#    {'_id': 54,
#     'Year/Année': '1959',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 55,
#     'Year/Année': '1959',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 8},
#    {'_id': 56,
#     'Year/Année': '1959',
#     'Month/Mois': 'November/novembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 8},
#    {'_id': 57,
#     'Year/Année': '1960',
#     'Month/Mois': 'August/août',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 58,
#     'Year/Année': '1960',
#     'Month/Mois': 'December/décembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 59,
#     'Year/Année': '1960',
#     'Month/Mois': 'July/juillet',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 60,
#     'Year/Année': '1960',
#     'Month/Mois': 'May/mai',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 61,
#     'Year/Année': '1960',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 8},
#    {'_id': 62,
#     'Year/Année': '1961',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 63,
#     'Year/Année': '1961',
#     'Month/Mois': 'August/août',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 64,
#     'Year/Année': '1961',
#     'Month/Mois': 'October/octobre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 8},
#    {'_id': 65,
#     'Year/Année': '1961',
#     'Month/Mois': 'February/février',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 9},
#    {'_id': 66,
#     'Year/Année': '1961',
#     'Month/Mois': 'March/mars',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 10},
#    {'_id': 67,
#     'Year/Année': '1962',
#     'Month/Mois': 'December/décembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 68,
#     'Year/Année': '1962',
#     'Month/Mois': 'May/mai',
#     'Municipality/Municipalité': 'SUDBURY',
#     'Totals / Totaux': 6},
#    {'_id': 69,
#     'Year/Année': '1962',
#     'Month/Mois': 'February/février',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 70,
#     'Year/Année': '1962',
#     'Month/Mois': 'June/juin',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 71,
#     'Year/Année': '1962',
#     'Month/Mois': 'August/août',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 11},
#    {'_id': 72,
#     'Year/Année': '1963',
#     'Month/Mois': 'November/novembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 73,
#     'Year/Année': '1963',
#     'Month/Mois': 'February/février',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 74,
#     'Year/Année': '1963',
#     'Month/Mois': 'December/décembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 8},
#    {'_id': 75,
#     'Year/Année': '1963',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 9},
#    {'_id': 76,
#     'Year/Année': '1963',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 9},
#    {'_id': 77,
#     'Year/Année': '1963',
#     'Month/Mois': 'March/mars',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 9},
#    {'_id': 78,
#     'Year/Année': '1963',
#     'Month/Mois': 'September/septembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 11},
#    {'_id': 79,
#     'Year/Année': '1964',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 80,
#     'Year/Année': '1964',
#     'Month/Mois': 'July/juillet',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 81,
#     'Year/Année': '1964',
#     'Month/Mois': 'September/septembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 82,
#     'Year/Année': '1964',
#     'Month/Mois': 'August/août',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 83,
#     'Year/Année': '1964',
#     'Month/Mois': 'November/novembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 8},
#    {'_id': 84,
#     'Year/Année': '1965',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 85,
#     'Year/Année': '1965',
#     'Month/Mois': 'October/octobre',
#     'Municipality/Municipalité': 'HAMILTON',
#     'Totals / Totaux': 6},
#    {'_id': 86,
#     'Year/Année': '1965',
#     'Month/Mois': 'February/février',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 87,
#     'Year/Année': '1965',
#     'Month/Mois': 'March/mars',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 88,
#     'Year/Année': '1965',
#     'Month/Mois': 'October/octobre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 89,
#     'Year/Année': '1965',
#     'Month/Mois': 'September/septembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 90,
#     'Year/Année': '1965',
#     'Month/Mois': 'December/décembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 8},
#    {'_id': 91,
#     'Year/Année': '1966',
#     'Month/Mois': 'May/mai',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 92,
#     'Year/Année': '1966',
#     'Month/Mois': 'October/octobre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 93,
#     'Year/Année': '1966',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 94,
#     'Year/Année': '1966',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 95,
#     'Year/Année': '1966',
#     'Month/Mois': 'September/septembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 96,
#     'Year/Année': '1966',
#     'Month/Mois': 'July/juillet',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 8},
#    {'_id': 97,
#     'Year/Année': '1966',
#     'Month/Mois': 'November/novembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 11},
#    {'_id': 98,
#     'Year/Année': '1967',
#     'Month/Mois': 'July/juillet',
#     'Municipality/Municipalité': 'HAMILTON',
#     'Totals / Totaux': 6},
#    {'_id': 99,
#     'Year/Année': '1967',
#     'Month/Mois': 'June/juin',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 100,
#     'Year/Année': '1967',
#     'Month/Mois': 'May/mai',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 101,
#     'Year/Année': '1967',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 8},
#    {'_id': 102,
#     'Year/Année': '1967',
#     'Month/Mois': 'July/juillet',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 9},
#    {'_id': 103,
#     'Year/Année': '1968',
#     'Month/Mois': 'July/juillet',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 104,
#     'Year/Année': '1968',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 8},
#    {'_id': 105,
#     'Year/Année': '1968',
#     'Month/Mois': 'March/mars',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 8},
#    {'_id': 106,
#     'Year/Année': '1968',
#     'Month/Mois': 'September/septembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 8},
#    {'_id': 107,
#     'Year/Année': '1968',
#     'Month/Mois': 'December/décembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 9},
#    {'_id': 108,
#     'Year/Année': '1968',
#     'Month/Mois': 'August/août',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 10},
#    {'_id': 109,
#     'Year/Année': '1968',
#     'Month/Mois': 'October/octobre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 11},
#    {'_id': 110,
#     'Year/Année': '1969',
#     'Month/Mois': 'June/juin',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 111,
#     'Year/Année': '1969',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 112,
#     'Year/Année': '1969',
#     'Month/Mois': 'August/août',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 113,
#     'Year/Année': '1969',
#     'Month/Mois': 'May/mai',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 114,
#     'Year/Année': '1969',
#     'Month/Mois': 'December/décembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 8},
#    {'_id': 115,
#     'Year/Année': '1969',
#     'Month/Mois': 'February/février',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 9},
#    {'_id': 116,
#     'Year/Année': '1969',
#     'Month/Mois': 'November/novembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 11},
#    {'_id': 117,
#     'Year/Année': '1970',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 118,
#     'Year/Année': '1970',
#     'Month/Mois': 'March/mars',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 119,
#     'Year/Année': '1970',
#     'Month/Mois': 'May/mai',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 120,
#     'Year/Année': '1970',
#     'Month/Mois': 'October/octobre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 121,
#     'Year/Année': '1970',
#     'Month/Mois': 'August/août',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 122,
#     'Year/Année': '1970',
#     'Month/Mois': 'December/décembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 123,
#     'Year/Année': '1970',
#     'Month/Mois': 'July/juillet',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 124,
#     'Year/Année': '1970',
#     'Month/Mois': 'November/novembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 8},
#    {'_id': 125,
#     'Year/Année': '1970',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 10},
#    {'_id': 126,
#     'Year/Année': '1970',
#     'Month/Mois': 'September/septembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 10},
#    {'_id': 127,
#     'Year/Année': '1971',
#     'Month/Mois': 'March/mars',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 128,
#     'Year/Année': '1971',
#     'Month/Mois': 'December/décembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 129,
#     'Year/Année': '1971',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 8},
#    {'_id': 130,
#     'Year/Année': '1971',
#     'Month/Mois': 'May/mai',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 9},
#    {'_id': 131,
#     'Year/Année': '1971',
#     'Month/Mois': 'September/septembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 10},
#    {'_id': 132,
#     'Year/Année': '1972',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 133,
#     'Year/Année': '1972',
#     'Month/Mois': 'July/juillet',
#     'Municipality/Municipalité': 'NORTH YORK',
#     'Totals / Totaux': 6},
#    {'_id': 134,
#     'Year/Année': '1972',
#     'Month/Mois': 'May/mai',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 135,
#     'Year/Année': '1972',
#     'Month/Mois': 'August/août',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 136,
#     'Year/Année': '1972',
#     'Month/Mois': 'March/mars',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 137,
#     'Year/Année': '1972',
#     'Month/Mois': 'September/septembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 138,
#     'Year/Année': '1972',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 8},
#    {'_id': 139,
#     'Year/Année': '1972',
#     'Month/Mois': 'July/juillet',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 9},
#    {'_id': 140,
#     'Year/Année': '1972',
#     'Month/Mois': 'October/octobre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 9},
#    {'_id': 141,
#     'Year/Année': '1972',
#     'Month/Mois': 'November/novembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 11},
#    {'_id': 142,
#     'Year/Année': '1973',
#     'Month/Mois': 'May/mai',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 143,
#     'Year/Année': '1973',
#     'Month/Mois': 'June/juin',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 144,
#     'Year/Année': '1973',
#     'Month/Mois': 'March/mars',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 145,
#     'Year/Année': '1973',
#     'Month/Mois': 'February/février',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 8},
#    {'_id': 146,
#     'Year/Année': '1973',
#     'Month/Mois': 'August/août',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 9},
#    {'_id': 147,
#     'Year/Année': '1973',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 9},
#    {'_id': 148,
#     'Year/Année': '1973',
#     'Month/Mois': 'September/septembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 9},
#    {'_id': 149,
#     'Year/Année': '1973',
#     'Month/Mois': 'November/novembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 10},
#    {'_id': 150,
#     'Year/Année': '1973',
#     'Month/Mois': 'December/décembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 12},
#    {'_id': 151,
#     'Year/Année': '1973',
#     'Month/Mois': 'July/juillet',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 12},
#    {'_id': 152,
#     'Year/Année': '1974',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 153,
#     'Year/Année': '1974',
#     'Month/Mois': 'July/juillet',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 154,
#     'Year/Année': '1974',
#     'Month/Mois': 'February/février',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 8},
#    {'_id': 155,
#     'Year/Année': '1974',
#     'Month/Mois': 'May/mai',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 8},
#    {'_id': 156,
#     'Year/Année': '1974',
#     'Month/Mois': 'September/septembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 8},
#    {'_id': 157,
#     'Year/Année': '1974',
#     'Month/Mois': 'October/octobre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 11},
#    {'_id': 158,
#     'Year/Année': '1974',
#     'Month/Mois': 'March/mars',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 12},
#    {'_id': 159,
#     'Year/Année': '1974',
#     'Month/Mois': 'November/novembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 12},
#    {'_id': 160,
#     'Year/Année': '1975',
#     'Month/Mois': 'March/mars',
#     'Municipality/Municipalité': 'OTTAWA',
#     'Totals / Totaux': 6},
#    {'_id': 161,
#     'Year/Année': '1975',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 162,
#     'Year/Année': '1975',
#     'Month/Mois': 'March/mars',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 8},
#    {'_id': 163,
#     'Year/Année': '1975',
#     'Month/Mois': 'October/octobre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 8},
#    {'_id': 164,
#     'Year/Année': '1975',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 9},
#    {'_id': 165,
#     'Year/Année': '1975',
#     'Month/Mois': 'June/juin',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 9},
#    {'_id': 166,
#     'Year/Année': '1975',
#     'Month/Mois': 'May/mai',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 11},
#    {'_id': 167,
#     'Year/Année': '1976',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 168,
#     'Year/Année': '1976',
#     'Month/Mois': 'August/août',
#     'Municipality/Municipalité': 'NORTH YORK',
#     'Totals / Totaux': 6},
#    {'_id': 169,
#     'Year/Année': '1976',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'OTTAWA',
#     'Totals / Totaux': 6},
#    {'_id': 170,
#     'Year/Année': '1976',
#     'Month/Mois': 'February/février',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 8},
#    {'_id': 171,
#     'Year/Année': '1976',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 9},
#    {'_id': 172,
#     'Year/Année': '1976',
#     'Month/Mois': 'June/juin',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 10},
#    {'_id': 173,
#     'Year/Année': '1976',
#     'Month/Mois': 'August/août',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 13},
#    {'_id': 174,
#     'Year/Année': '1976',
#     'Month/Mois': 'December/décembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 13},
#    {'_id': 175,
#     'Year/Année': '1977',
#     'Month/Mois': 'February/février',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 176,
#     'Year/Année': '1977',
#     'Month/Mois': 'September/septembre',
#     'Municipality/Municipalité': 'OTTAWA',
#     'Totals / Totaux': 6},
#    {'_id': 177,
#     'Year/Année': '1977',
#     'Month/Mois': 'September/septembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 6},
#    {'_id': 178,
#     'Year/Année': '1977',
#     'Month/Mois': 'July/juillet',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 8},
#    {'_id': 179,
#     'Year/Année': '1977',
#     'Month/Mois': 'May/mai',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 8},
#    {'_id': 180,
#     'Year/Année': '1977',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 9},
#    {'_id': 181,
#     'Year/Année': '1977',
#     'Month/Mois': 'August/août',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 9},
#    {'_id': 182,
#     'Year/Année': '1977',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 9},
#    {'_id': 183,
#     'Year/Année': '1977',
#     'Month/Mois': 'March/mars',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 9},
#    {'_id': 184,
#     'Year/Année': '1977',
#     'Month/Mois': 'December/décembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 16},
#    {'_id': 185,
#     'Year/Année': '1977',
#     'Month/Mois': 'October/octobre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 20},
#    {'_id': 186,
#     'Year/Année': '1978',
#     'Month/Mois': 'October/octobre',
#     'Municipality/Municipalité': 'OTTAWA',
#     'Totals / Totaux': 6},
#    {'_id': 187,
#     'Year/Année': '1978',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 188,
#     'Year/Année': '1978',
#     'Month/Mois': 'August/août',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 189,
#     'Year/Année': '1978',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'NORTH YORK',
#     'Totals / Totaux': 7},
#    {'_id': 190,
#     'Year/Année': '1978',
#     'Month/Mois': 'July/juillet',
#     'Municipality/Municipalité': 'NORTH YORK',
#     'Totals / Totaux': 7},
#    {'_id': 191,
#     'Year/Année': '1978',
#     'Month/Mois': 'June/juin',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 192,
#     'Year/Année': '1978',
#     'Month/Mois': 'March/mars',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 193,
#     'Year/Année': '1978',
#     'Month/Mois': 'May/mai',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 194,
#     'Year/Année': '1978',
#     'Month/Mois': 'September/septembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 195,
#     'Year/Année': '1978',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 8},
#    {'_id': 196,
#     'Year/Année': '1978',
#     'Month/Mois': 'October/octobre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 9},
#    {'_id': 197,
#     'Year/Année': '1979',
#     'Month/Mois': 'December/décembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 198,
#     'Year/Année': '1979',
#     'Month/Mois': 'May/mai',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 7},
#    {'_id': 199,
#     'Year/Année': '1979',
#     'Month/Mois': 'July/juillet',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 8},
#    {'_id': 200,
#     'Year/Année': '1979',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 9},
#    {'_id': 201,
#     'Year/Année': '1979',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 9},
#    {'_id': 202,
#     'Year/Année': '1979',
#     'Month/Mois': 'March/mars',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 10},
#    {'_id': 203,
#     'Year/Année': '1979',
#     'Month/Mois': 'October/octobre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 10},
#    {'_id': 204,
#     'Year/Année': '1979',
#     'Month/Mois': 'November/novembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 11},
#    {'_id': 205,
#     'Year/Année': '1979',
#     'Month/Mois': 'September/septembre',
#     'Municipality/Municipalité': 'TORONTO',
#     'Totals / Totaux': 11},
#    {'_id': 206,
#     'Year/Année': '1980',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'BROCK T',
#     'Totals / Totaux': 6},
#    {'_id': 207,
#     'Year/Année': '1980',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'E ZORRA-TAVIS T',
#     'Totals / Totaux': 6},
#    {'_id': 208,
#     'Year/Année': '1980',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'HALTON HILLS',
#     'Totals / Totaux': 6},
#    {'_id': 209,
#     'Year/Année': '1980',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'HEARST',
#     'Totals / Totaux': 6},
#    {'_id': 210,
#     'Year/Année': '1980',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'PALMERSTON',
#     'Totals / Totaux': 6},
#    {'_id': 211,
#     'Year/Année': '1980',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'SIOUX LOOKOUT',
#     'Totals / Totaux': 6},
#    {'_id': 212,
#     'Year/Année': '1980',
#     'Month/Mois': 'August/août',
#     'Municipality/Municipalité': 'AURORA',
#     'Totals / Totaux': 6},
#    {'_id': 213,
#     'Year/Année': '1980',
#     'Month/Mois': 'August/août',
#     'Municipality/Municipalité': 'BROCK T',
#     'Totals / Totaux': 6},
#    {'_id': 214,
#     'Year/Année': '1980',
#     'Month/Mois': 'August/août',
#     'Municipality/Municipalité': 'EXETER',
#     'Totals / Totaux': 6},
#    {'_id': 215,
#     'Year/Année': '1980',
#     'Month/Mois': 'August/août',
#     'Municipality/Municipalité': 'FORT FRANCES',
#     'Totals / Totaux': 6},
#    {'_id': 216,
#     'Year/Année': '1980',
#     'Month/Mois': 'August/août',
#     'Municipality/Municipalité': 'GRAVENHURST',
#     'Totals / Totaux': 6},
#    {'_id': 217,
#     'Year/Année': '1980',
#     'Month/Mois': 'August/août',
#     'Municipality/Municipalité': 'INGERSOLL',
#     'Totals / Totaux': 6},
#    {'_id': 218,
#     'Year/Année': '1980',
#     'Month/Mois': 'August/août',
#     'Municipality/Municipalité': 'KENYON T',
#     'Totals / Totaux': 6},
#    {'_id': 219,
#     'Year/Année': '1980',
#     'Month/Mois': 'August/août',
#     'Municipality/Municipalité': 'MARKDALE',
#     'Totals / Totaux': 6},
#    {'_id': 220,
#     'Year/Année': '1980',
#     'Month/Mois': 'August/août',
#     'Municipality/Municipalité': 'MARKHAM',
#     'Totals / Totaux': 6},
#    {'_id': 221,
#     'Year/Année': '1980',
#     'Month/Mois': 'August/août',
#     'Municipality/Municipalité': 'MEAFORD',
#     'Totals / Totaux': 6},
#    {'_id': 222,
#     'Year/Année': '1980',
#     'Month/Mois': 'December/décembre',
#     'Municipality/Municipalité': 'BURKS FALLS',
#     'Totals / Totaux': 6},
#    {'_id': 223,
#     'Year/Année': '1980',
#     'Month/Mois': 'December/décembre',
#     'Municipality/Municipalité': 'HANOVER',
#     'Totals / Totaux': 6},
#    {'_id': 224,
#     'Year/Année': '1980',
#     'Month/Mois': 'December/décembre',
#     'Municipality/Municipalité': 'SCUGOG T',
#     'Totals / Totaux': 6},
#    {'_id': 225,
#     'Year/Année': '1980',
#     'Month/Mois': 'December/décembre',
#     'Municipality/Municipalité': 'TINY T',
#     'Totals / Totaux': 6},
#    {'_id': 226,
#     'Year/Année': '1980',
#     'Month/Mois': 'December/décembre',
#     'Municipality/Municipalité': 'WATERLOO',
#     'Totals / Totaux': 6},
#    {'_id': 227,
#     'Year/Année': '1980',
#     'Month/Mois': 'February/février',
#     'Municipality/Municipalité': 'ALLISTON',
#     'Totals / Totaux': 6},
#    {'_id': 228,
#     'Year/Année': '1980',
#     'Month/Mois': 'February/février',
#     'Municipality/Municipalité': 'CAMPBELLFORD',
#     'Totals / Totaux': 6},
#    {'_id': 229,
#     'Year/Année': '1980',
#     'Month/Mois': 'February/février',
#     'Municipality/Municipalité': 'CLINTON',
#     'Totals / Totaux': 6},
#    {'_id': 230,
#     'Year/Année': '1980',
#     'Month/Mois': 'February/février',
#     'Municipality/Municipalité': 'FERGUS',
#     'Totals / Totaux': 6},
#    {'_id': 231,
#     'Year/Année': '1980',
#     'Month/Mois': 'February/février',
#     'Municipality/Municipalité': 'IROQUOIS FALLS',
#     'Totals / Totaux': 6},
#    {'_id': 232,
#     'Year/Année': '1980',
#     'Month/Mois': 'February/février',
#     'Municipality/Municipalité': 'KINCARDINE T',
#     'Totals / Totaux': 6},
#    {'_id': 233,
#     'Year/Année': '1980',
#     'Month/Mois': 'February/février',
#     'Municipality/Municipalité': 'NEWBURY',
#     'Totals / Totaux': 6},
#    {'_id': 234,
#     'Year/Année': '1980',
#     'Month/Mois': 'February/février',
#     'Municipality/Municipalité': 'WALLACEBURG',
#     'Totals / Totaux': 6},
#    {'_id': 235,
#     'Year/Année': '1980',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'AMHERSTBURG',
#     'Totals / Totaux': 6},
#    {'_id': 236,
#     'Year/Année': '1980',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'HALDIMAND',
#     'Totals / Totaux': 6},
#    {'_id': 237,
#     'Year/Année': '1980',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'MIDLAND',
#     'Totals / Totaux': 6},
#    {'_id': 238,
#     'Year/Année': '1980',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'NIAGARA-ON-LAKE',
#     'Totals / Totaux': 6},
#    {'_id': 239,
#     'Year/Année': '1980',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'OXFORD T',
#     'Totals / Totaux': 6},
#    {'_id': 240,
#     'Year/Année': '1980',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'PALMERSTON',
#     'Totals / Totaux': 6},
#    {'_id': 241,
#     'Year/Année': '1980',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'PENETANGUISHENE',
#     'Totals / Totaux': 6},
#    {'_id': 242,
#     'Year/Année': '1980',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'PORT HOPE',
#     'Totals / Totaux': 6},
#    {'_id': 243,
#     'Year/Année': '1980',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'STONEY CREEK',
#     'Totals / Totaux': 6},
#    {'_id': 244,
#     'Year/Année': '1980',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'WIARTON',
#     'Totals / Totaux': 6},
#    {'_id': 245,
#     'Year/Année': '1980',
#     'Month/Mois': 'July/juillet',
#     'Municipality/Municipalité': 'ARNPRIOR',
#     'Totals / Totaux': 6},
#    {'_id': 246,
#     'Year/Année': '1980',
#     'Month/Mois': 'July/juillet',
#     'Municipality/Municipalité': 'ELLIOT LAKE',
#     'Totals / Totaux': 6},
#    {'_id': 247,
#     'Year/Année': '1980',
#     'Month/Mois': 'July/juillet',
#     'Municipality/Municipalité': 'FORT FRANCES',
#     'Totals / Totaux': 6},
#    {'_id': 248,
#     'Year/Année': '1980',
#     'Month/Mois': 'July/juillet',
#     'Municipality/Municipalité': 'GANANOQUE',
#     'Totals / Totaux': 6},
#    {'_id': 249,
#     'Year/Année': '1980',
#     'Month/Mois': 'July/juillet',
#     'Municipality/Municipalité': 'IROQUOIS FALLS',
#     'Totals / Totaux': 6},
#    {'_id': 250,
#     'Year/Année': '1980',
#     'Month/Mois': 'July/juillet',
#     'Municipality/Municipalité': 'KENYON T',
#     'Totals / Totaux': 6},
#    {'_id': 251,
#     'Year/Année': '1980',
#     'Month/Mois': 'July/juillet',
#     'Municipality/Municipalité': 'MUSKOKA LAKES T',
#     'Totals / Totaux': 6},
#    {'_id': 252,
#     'Year/Année': '1980',
#     'Month/Mois': 'July/juillet',
#     'Municipality/Municipalité': 'STMarYS',
#     'Totals / Totaux': 6},
#    {'_id': 253,
#     'Year/Année': '1980',
#     'Month/Mois': 'July/juillet',
#     'Municipality/Municipalité': 'STONEY CREEK',
#     'Totals / Totaux': 6},
#    {'_id': 254,
#     'Year/Année': '1980',
#     'Month/Mois': 'June/juin',
#     'Municipality/Municipalité': 'ALLISTON',
#     'Totals / Totaux': 6},
#    {'_id': 255,
#     'Year/Année': '1980',
#     'Month/Mois': 'June/juin',
#     'Municipality/Municipalité': 'ARNPRIOR',
#     'Totals / Totaux': 6},
#    {'_id': 256,
#     'Year/Année': '1980',
#     'Month/Mois': 'June/juin',
#     'Municipality/Municipalité': 'DUNDAS',
#     'Totals / Totaux': 6},
#    {'_id': 257,
#     'Year/Année': '1980',
#     'Month/Mois': 'June/juin',
#     'Municipality/Municipalité': 'DUNNVILLE',
#     'Totals / Totaux': 6},
#    {'_id': 258,
#     'Year/Année': '1980',
#     'Month/Mois': 'June/juin',
#     'Municipality/Municipalité': 'HALDIMAND',
#     'Totals / Totaux': 6},
#    {'_id': 259,
#     'Year/Année': '1980',
#     'Month/Mois': 'June/juin',
#     'Municipality/Municipalité': 'HANOVER',
#     'Totals / Totaux': 6},
#    {'_id': 260,
#     'Year/Année': '1980',
#     'Month/Mois': 'June/juin',
#     'Municipality/Municipalité': 'KAPUSKASING',
#     'Totals / Totaux': 6},
#    {'_id': 261,
#     'Year/Année': '1980',
#     'Month/Mois': 'June/juin',
#     'Municipality/Municipalité': 'KENYON T',
#     'Totals / Totaux': 6},
#    {'_id': 262,
#     'Year/Année': '1980',
#     'Month/Mois': 'June/juin',
#     'Municipality/Municipalité': 'PARIS',
#     'Totals / Totaux': 6},
#    {'_id': 263,
#     'Year/Année': '1980',
#     'Month/Mois': 'June/juin',
#     'Municipality/Municipalité': 'RICHMOND T',
#     'Totals / Totaux': 6},
#    {'_id': 264,
#     'Year/Année': '1980',
#     'Month/Mois': 'June/juin',
#     'Municipality/Municipalité': 'SCUGOG T',
#     'Totals / Totaux': 6},
#    {'_id': 265,
#     'Year/Année': '1980',
#     'Month/Mois': 'June/juin',
#     'Municipality/Municipalité': 'SHELBURNE',
#     'Totals / Totaux': 6},
#    {'_id': 266,
#     'Year/Année': '1980',
#     'Month/Mois': 'June/juin',
#     'Municipality/Municipalité': 'WALKERTON',
#     'Totals / Totaux': 6},
#    {'_id': 267,
#     'Year/Année': '1980',
#     'Month/Mois': 'June/juin',
#     'Municipality/Municipalité': 'WOOLWICH T',
#     'Totals / Totaux': 6},
#    {'_id': 268,
#     'Year/Année': '1980',
#     'Month/Mois': 'March/mars',
#     'Municipality/Municipalité': 'DEER LAKE',
#     'Totals / Totaux': 6},
#    {'_id': 269,
#     'Year/Année': '1980',
#     'Month/Mois': 'March/mars',
#     'Municipality/Municipalité': 'HANOVER',
#     'Totals / Totaux': 6},
#    {'_id': 270,
#     'Year/Année': '1980',
#     'Month/Mois': 'March/mars',
#     'Municipality/Municipalité': 'HEARST',
#     'Totals / Totaux': 6},
#    {'_id': 271,
#     'Year/Année': '1980',
#     'Month/Mois': 'March/mars',
#     'Municipality/Municipalité': 'MARKHAM',
#     'Totals / Totaux': 6},
#    {'_id': 272,
#     'Year/Année': '1980',
#     'Month/Mois': 'March/mars',
#     'Municipality/Municipalité': 'MOUNT FOREST',
#     'Totals / Totaux': 6},
#    {'_id': 273,
#     'Year/Année': '1980',
#     'Month/Mois': 'March/mars',
#     'Municipality/Municipalité': 'STURGEON FALLS',
#     'Totals / Totaux': 6},
#    {'_id': 274,
#     'Year/Année': '1980',
#     'Month/Mois': 'March/mars',
#     'Municipality/Municipalité': 'WATERLOO',
#     'Totals / Totaux': 6},
#    {'_id': 275,
#     'Year/Année': '1980',
#     'Month/Mois': 'May/mai',
#     'Municipality/Municipalité': 'ATIKOKAN T',
#     'Totals / Totaux': 6},
#    {'_id': 276,
#     'Year/Année': '1980',
#     'Month/Mois': 'May/mai',
#     'Municipality/Municipalité': 'BROCK T',
#     'Totals / Totaux': 6},
#    {'_id': 277,
#     'Year/Année': '1980',
#     'Month/Mois': 'May/mai',
#     'Municipality/Municipalité': 'DURHAM',
#     'Totals / Totaux': 6},
#    {'_id': 278,
#     'Year/Année': '1980',
#     'Month/Mois': 'May/mai',
#     'Municipality/Municipalité': 'EXETER',
#     'Totals / Totaux': 6},
#    {'_id': 279,
#     'Year/Année': '1980',
#     'Month/Mois': 'May/mai',
#     'Municipality/Municipalité': 'LITTLE CURRENT',
#     'Totals / Totaux': 6},
#    {'_id': 280,
#     'Year/Année': '1980',
#     'Month/Mois': 'May/mai',
#     'Municipality/Municipalité': 'PENETANGUISHENE',
#     'Totals / Totaux': 6},
#    {'_id': 281,
#     'Year/Année': '1980',
#     'Month/Mois': 'May/mai',
#     'Municipality/Municipalité': 'SIOUX LOOKOUT',
#     'Totals / Totaux': 6},
#    {'_id': 282,
#     'Year/Année': '1980',
#     'Month/Mois': 'November/novembre',
#     'Municipality/Municipalité': 'DRYDEN',
#     'Totals / Totaux': 6},
#    {'_id': 283,
#     'Year/Année': '1980',
#     'Month/Mois': 'November/novembre',
#     'Municipality/Municipalité': 'KAPUSKASING',
#     'Totals / Totaux': 6},
#    {'_id': 284,
#     'Year/Année': '1980',
#     'Month/Mois': 'November/novembre',
#     'Municipality/Municipalité': 'MARKDALE',
#     'Totals / Totaux': 6},
#    {'_id': 285,
#     'Year/Année': '1980',
#     'Month/Mois': 'November/novembre',
#     'Municipality/Municipalité': 'MEAFORD',
#     'Totals / Totaux': 6},
#    {'_id': 286,
#     'Year/Année': '1980',
#     'Month/Mois': 'November/novembre',
#     'Municipality/Municipalité': 'OXFORD T',
#     'Totals / Totaux': 6},
#    {'_id': 287,
#     'Year/Année': '1980',
#     'Month/Mois': 'November/novembre',
#     'Municipality/Municipalité': 'THESSALON',
#     'Totals / Totaux': 6},
#    {'_id': 288,
#     'Year/Année': '1980',
#     'Month/Mois': 'November/novembre',
#     'Municipality/Municipalité': 'WIARTON',
#     'Totals / Totaux': 6},
#    {'_id': 289,
#     'Year/Année': '1980',
#     'Month/Mois': 'October/octobre',
#     'Municipality/Municipalité': 'BURKS FALLS',
#     'Totals / Totaux': 6},
#    {'_id': 290,
#     'Year/Année': '1980',
#     'Month/Mois': 'October/octobre',
#     'Municipality/Municipalité': 'COCHRANE',
#     'Totals / Totaux': 6},
#    {'_id': 291,
#     'Year/Année': '1980',
#     'Month/Mois': 'October/octobre',
#     'Municipality/Municipalité': 'DRYDEN',
#     'Totals / Totaux': 6},
#    {'_id': 292,
#     'Year/Année': '1980',
#     'Month/Mois': 'October/octobre',
#     'Municipality/Municipalité': 'FLAMBOROUGH T',
#     'Totals / Totaux': 6},
#    {'_id': 293,
#     'Year/Année': '1980',
#     'Month/Mois': 'October/octobre',
#     'Municipality/Municipalité': 'HANOVER',
#     'Totals / Totaux': 6},
#    {'_id': 294,
#     'Year/Année': '1980',
#     'Month/Mois': 'October/octobre',
#     'Municipality/Municipalité': 'MATTAWA',
#     'Totals / Totaux': 6},
#    {'_id': 295,
#     'Year/Année': '1980',
#     'Month/Mois': 'October/octobre',
#     'Municipality/Municipalité': 'PICKERING',
#     'Totals / Totaux': 6},
#    {'_id': 296,
#     'Year/Année': '1980',
#     'Month/Mois': 'October/octobre',
#     'Municipality/Municipalité': 'PICTON',
#     'Totals / Totaux': 6},
#    {'_id': 297,
#     'Year/Année': '1980',
#     'Month/Mois': 'October/octobre',
#     'Municipality/Municipalité': 'SIDNEY T',
#     'Totals / Totaux': 6},
#    {'_id': 298,
#     'Year/Année': '1980',
#     'Month/Mois': 'October/octobre',
#     'Municipality/Municipalité': 'SOUTHAMPTON',
#     'Totals / Totaux': 6},
#    {'_id': 299,
#     'Year/Année': '1980',
#     'Month/Mois': 'October/octobre',
#     'Municipality/Municipalité': 'WALKERTON',
#     'Totals / Totaux': 6},
#    {'_id': 300,
#     'Year/Année': '1980',
#     'Month/Mois': 'September/septembre',
#     'Municipality/Municipalité': 'CALEDON',
#     'Totals / Totaux': 6},
#    {'_id': 301,
#     'Year/Année': '1980',
#     'Month/Mois': 'September/septembre',
#     'Municipality/Municipalité': 'CHESLEY',
#     'Totals / Totaux': 6},
#    {'_id': 302,
#     'Year/Année': '1980',
#     'Month/Mois': 'September/septembre',
#     'Municipality/Municipalité': 'CLINTON',
#     'Totals / Totaux': 6},
#    {'_id': 303,
#     'Year/Année': '1980',
#     'Month/Mois': 'September/septembre',
#     'Municipality/Municipalité': 'DRYDEN',
#     'Totals / Totaux': 6},
#    {'_id': 304,
#     'Year/Année': '1980',
#     'Month/Mois': 'September/septembre',
#     'Municipality/Municipalité': 'HANOVER',
#     'Totals / Totaux': 6},
#    {'_id': 305,
#     'Year/Année': '1980',
#     'Month/Mois': 'September/septembre',
#     'Municipality/Municipalité': 'MEAFORD',
#     'Totals / Totaux': 6},
#    {'_id': 306,
#     'Year/Année': '1980',
#     'Month/Mois': 'September/septembre',
#     'Municipality/Municipalité': 'NIAGARA-ON-LAKE',
#     'Totals / Totaux': 6},
#    {'_id': 307,
#     'Year/Année': '1980',
#     'Month/Mois': 'September/septembre',
#     'Municipality/Municipalité': 'OXFORD T',
#     'Totals / Totaux': 6},
#    {'_id': 308,
#     'Year/Année': '1980',
#     'Month/Mois': 'September/septembre',
#     'Municipality/Municipalité': 'PENETANGUISHENE',
#     'Totals / Totaux': 6},
#    {'_id': 309,
#     'Year/Année': '1980',
#     'Month/Mois': 'September/septembre',
#     'Municipality/Municipalité': 'WALKERTON',
#     'Totals / Totaux': 6},
#    {'_id': 310,
#     'Year/Année': '1980',
#     'Month/Mois': 'September/septembre',
#     'Municipality/Municipalité': 'WIARTON',
#     'Totals / Totaux': 6},
#    {'_id': 311,
#     'Year/Année': '1980',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'ARNPRIOR',
#     'Totals / Totaux': 7},
#    {'_id': 312,
#     'Year/Année': '1980',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'BANCROFT',
#     'Totals / Totaux': 7},
#    {'_id': 313,
#     'Year/Année': '1980',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'ELLIOT LAKE',
#     'Totals / Totaux': 7},
#    {'_id': 314,
#     'Year/Année': '1980',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'LINCOLN',
#     'Totals / Totaux': 7},
#    {'_id': 315,
#     'Year/Année': '1980',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'MIDLAND',
#     'Totals / Totaux': 7},
#    {'_id': 316,
#     'Year/Année': '1980',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'NIAGARA-ON-LAKE',
#     'Totals / Totaux': 7},
#    {'_id': 317,
#     'Year/Année': '1980',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'PARRY SOUND',
#     'Totals / Totaux': 7},
#    {'_id': 318,
#     'Year/Année': '1980',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'PETROLIA',
#     'Totals / Totaux': 7},
#    {'_id': 319,
#     'Year/Année': '1980',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'SHELBURNE',
#     'Totals / Totaux': 7},
#    {'_id': 320,
#     'Year/Année': '1980',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'TINY T',
#     'Totals / Totaux': 7},
#    {'_id': 321,
#     'Year/Année': '1980',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'TRENTON',
# ...
#     'Municipality/Municipalité': 'TILLSONBURG',
#     'Totals / Totaux': 17},
#    {'_id': 900,
#     'Year/Année': '1980',
#     'Month/Mois': 'November/novembre',
#     'Municipality/Municipalité': 'AJAX',
#     'Totals / Totaux': 17},
#    {'_id': 901,
#     'Year/Année': '1980',
#     'Month/Mois': 'November/novembre',
#     'Municipality/Municipalité': 'GRIMSBY',
#     'Totals / Totaux': 17},
#    {'_id': 902,
#     'Year/Année': '1980',
#     'Month/Mois': 'November/novembre',
#     'Municipality/Municipalité': 'NEWCASTLE',
#     'Totals / Totaux': 17},
#    {'_id': 903,
#     'Year/Année': '1980',
#     'Month/Mois': 'November/novembre',
#     'Municipality/Municipalité': 'PORT COLBORNE',
#     'Totals / Totaux': 17},
#    {'_id': 904,
#     'Year/Année': '1980',
#     'Month/Mois': 'November/novembre',
#     'Municipality/Municipalité': 'TILLSONBURG',
#     'Totals / Totaux': 17},
#    {'_id': 905,
#     'Year/Année': '1980',
#     'Month/Mois': 'October/octobre',
#     'Municipality/Municipalité': 'MILTON',
#     'Totals / Totaux': 17},
#    {'_id': 906,
#     'Year/Année': '1980',
#     'Month/Mois': 'September/septembre',
#     'Municipality/Municipalité': 'BRACEBRIDGE',
#     'Totals / Totaux': 17},
#    {'_id': 907,
#     'Year/Année': '1980',
#     'Month/Mois': 'September/septembre',
#     'Municipality/Municipalité': 'COLLINGWOOD',
#     'Totals / Totaux': 17},
#    {'_id': 908,
#     'Year/Année': '1980',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'COBOURG',
#     'Totals / Totaux': 18},
#    {'_id': 909,
#     'Year/Année': '1980',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'WOODSTOCK',
#     'Totals / Totaux': 18},
#    {'_id': 910,
#     'Year/Année': '1980',
#     'Month/Mois': 'August/août',
#     'Municipality/Municipalité': 'WOODSTOCK',
#     'Totals / Totaux': 18},
#    {'_id': 911,
#     'Year/Année': '1980',
#     'Month/Mois': 'February/février',
#     'Municipality/Municipalité': 'BRACEBRIDGE',
#     'Totals / Totaux': 18},
#    {'_id': 912,
#     'Year/Année': '1980',
#     'Month/Mois': 'February/février',
#     'Municipality/Municipalité': 'KIRKLAND LAKE',
#     'Totals / Totaux': 18},
#    {'_id': 913,
#     'Year/Année': '1980',
#     'Month/Mois': 'February/février',
#     'Municipality/Municipalité': 'STRATFORD',
#     'Totals / Totaux': 18},
#    {'_id': 914,
#     'Year/Année': '1980',
#     'Month/Mois': 'February/février',
#     'Municipality/Municipalité': 'TINY T',
#     'Totals / Totaux': 18},
#    {'_id': 915,
#     'Year/Année': '1980',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'BRACEBRIDGE',
#     'Totals / Totaux': 18},
#    {'_id': 916,
#     'Year/Année': '1980',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'COBOURG',
#     'Totals / Totaux': 18},
#    {'_id': 917,
#     'Year/Année': '1980',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'GRIMSBY',
#     'Totals / Totaux': 18},
#    {'_id': 918,
#     'Year/Année': '1980',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'WHITBY',
#     'Totals / Totaux': 18},
#    {'_id': 919,
#     'Year/Année': '1980',
#     'Month/Mois': 'July/juillet',
#     'Municipality/Municipalité': 'PARRY SOUND',
#     'Totals / Totaux': 18},
#    {'_id': 920,
#     'Year/Année': '1980',
#     'Month/Mois': 'July/juillet',
#     'Municipality/Municipalité': 'TIMMINS',
#     'Totals / Totaux': 18},
#    {'_id': 921,
#     'Year/Année': '1980',
#     'Month/Mois': 'June/juin',
#     'Municipality/Municipalité': 'HAWKESBURY',
#     'Totals / Totaux': 18},
#    {'_id': 922,
#     'Year/Année': '1980',
#     'Month/Mois': 'June/juin',
#     'Municipality/Municipalité': 'WOODSTOCK',
#     'Totals / Totaux': 18},
#    {'_id': 923,
#     'Year/Année': '1980',
#     'Month/Mois': 'March/mars',
#     'Municipality/Municipalité': 'RENFREW',
#     'Totals / Totaux': 18},
#    {'_id': 924,
#     'Year/Année': '1980',
#     'Month/Mois': 'March/mars',
#     'Municipality/Municipalité': 'STRATFORD',
#     'Totals / Totaux': 18},
#    {'_id': 925,
#     'Year/Année': '1980',
#     'Month/Mois': 'May/mai',
#     'Municipality/Municipalité': 'BRACEBRIDGE',
#     'Totals / Totaux': 18},
#    {'_id': 926,
#     'Year/Année': '1980',
#     'Month/Mois': 'May/mai',
#     'Municipality/Municipalité': 'NEWCASTLE',
#     'Totals / Totaux': 18},
#    {'_id': 927,
#     'Year/Année': '1980',
#     'Month/Mois': 'May/mai',
#     'Municipality/Municipalité': 'WOODSTOCK',
#     'Totals / Totaux': 18},
#    {'_id': 928,
#     'Year/Année': '1980',
#     'Month/Mois': 'November/novembre',
#     'Municipality/Municipalité': 'WHITBY',
#     'Totals / Totaux': 18},
#    {'_id': 929,
#     'Year/Année': '1980',
#     'Month/Mois': 'October/octobre',
#     'Municipality/Municipalité': 'KIRKLAND LAKE',
#     'Totals / Totaux': 18},
#    {'_id': 930,
#     'Year/Année': '1980',
#     'Month/Mois': 'October/octobre',
#     'Municipality/Municipalité': 'PEMBROKE',
#     'Totals / Totaux': 18},
#    {'_id': 931,
#     'Year/Année': '1980',
#     'Month/Mois': 'September/septembre',
#     'Municipality/Municipalité': 'COBOURG',
#     'Totals / Totaux': 18},
#    {'_id': 932,
#     'Year/Année': '1980',
#     'Month/Mois': 'September/septembre',
#     'Municipality/Municipalité': 'STRATFORD',
#     'Totals / Totaux': 18},
#    {'_id': 933,
#     'Year/Année': '1980',
#     'Month/Mois': 'August/août',
#     'Municipality/Municipalité': 'LEAMINGTON',
#     'Totals / Totaux': 19},
#    {'_id': 934,
#     'Year/Année': '1980',
#     'Month/Mois': 'August/août',
#     'Municipality/Municipalité': 'TIMMINS',
#     'Totals / Totaux': 19},
#    {'_id': 935,
#     'Year/Année': '1980',
#     'Month/Mois': 'December/décembre',
#     'Municipality/Municipalité': 'TRENTON',
#     'Totals / Totaux': 19},
#    {'_id': 936,
#     'Year/Année': '1980',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'RICHMOND T',
#     'Totals / Totaux': 19},
#    {'_id': 937,
#     'Year/Année': '1980',
#     'Month/Mois': 'July/juillet',
#     'Municipality/Municipalité': 'STRATFORD',
#     'Totals / Totaux': 19},
#    {'_id': 938,
#     'Year/Année': '1980',
#     'Month/Mois': 'March/mars',
#     'Municipality/Municipalité': 'TILLSONBURG',
#     'Totals / Totaux': 19},
#    {'_id': 939,
#     'Year/Année': '1980',
#     'Month/Mois': 'May/mai',
#     'Municipality/Municipalité': 'LINDSAY',
#     'Totals / Totaux': 19},
#    {'_id': 940,
#     'Year/Année': '1980',
#     'Month/Mois': 'October/octobre',
#     'Municipality/Municipalité': 'HAWKESBURY',
#     'Totals / Totaux': 19},
#    {'_id': 941,
#     'Year/Année': '1980',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'BARRIE',
#     'Totals / Totaux': 20},
#    {'_id': 942,
#     'Year/Année': '1980',
#     'Month/Mois': 'August/août',
#     'Municipality/Municipalité': 'HUNTSVILLE',
#     'Totals / Totaux': 20},
#    {'_id': 943,
#     'Year/Année': '1980',
#     'Month/Mois': 'August/août',
#     'Municipality/Municipalité': 'OWEN SOUND',
#     'Totals / Totaux': 20},
#    {'_id': 944,
#     'Year/Année': '1980',
#     'Month/Mois': 'August/août',
#     'Municipality/Municipalité': 'TILLSONBURG',
#     'Totals / Totaux': 20},
#    {'_id': 945,
#     'Year/Année': '1980',
#     'Month/Mois': 'December/décembre',
#     'Municipality/Municipalité': 'SIMCOE',
#     'Totals / Totaux': 20},
#    {'_id': 946,
#     'Year/Année': '1980',
#     'Month/Mois': 'February/février',
#     'Municipality/Municipalité': 'COBOURG',
#     'Totals / Totaux': 20},
#    {'_id': 947,
#     'Year/Année': '1980',
#     'Month/Mois': 'February/février',
#     'Municipality/Municipalité': 'COLLINGWOOD',
#     'Totals / Totaux': 20},
#    {'_id': 948,
#     'Year/Année': '1980',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'PARRY SOUND',
#     'Totals / Totaux': 20},
#    {'_id': 949,
#     'Year/Année': '1980',
#     'Month/Mois': 'July/juillet',
#     'Municipality/Municipalité': 'GRIMSBY',
#     'Totals / Totaux': 20},
#    {'_id': 950,
#     'Year/Année': '1980',
#     'Month/Mois': 'July/juillet',
#     'Municipality/Municipalité': 'OWEN SOUND',
#     'Totals / Totaux': 20},
#    {'_id': 951,
#     'Year/Année': '1980',
#     'Month/Mois': 'March/mars',
#     'Municipality/Municipalité': 'WHITBY',
#     'Totals / Totaux': 20},
#    {'_id': 952,
#     'Year/Année': '1980',
#     'Month/Mois': 'May/mai',
#     'Municipality/Municipalité': 'RICHMOND T',
#     'Totals / Totaux': 20},
#    {'_id': 953,
#     'Year/Année': '1980',
#     'Month/Mois': 'November/novembre',
#     'Municipality/Municipalité': 'STRATFORD',
#     'Totals / Totaux': 20},
#    {'_id': 954,
#     'Year/Année': '1980',
#     'Month/Mois': 'November/novembre',
#     'Municipality/Municipalité': 'WOODSTOCK',
#     'Totals / Totaux': 20},
#    {'_id': 955,
#     'Year/Année': '1980',
#     'Month/Mois': 'October/octobre',
#     'Municipality/Municipalité': 'COBOURG',
#     'Totals / Totaux': 20},
#    {'_id': 956,
#     'Year/Année': '1980',
#     'Month/Mois': 'October/octobre',
#     'Municipality/Municipalité': 'ORANGEVILLE',
#     'Totals / Totaux': 20},
#    {'_id': 957,
#     'Year/Année': '1980',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'PEMBROKE',
#     'Totals / Totaux': 21},
#    {'_id': 958,
#     'Year/Année': '1980',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'RICHMOND HILL',
#     'Totals / Totaux': 21},
#    {'_id': 959,
#     'Year/Année': '1980',
#     'Month/Mois': 'August/août',
#     'Municipality/Municipalité': 'GRIMSBY',
#     'Totals / Totaux': 21},
#    {'_id': 960,
#     'Year/Année': '1980',
#     'Month/Mois': 'August/août',
#     'Municipality/Municipalité': 'PEMBROKE',
#     'Totals / Totaux': 21},
#    {'_id': 961,
#     'Year/Année': '1980',
#     'Month/Mois': 'December/décembre',
#     'Municipality/Municipalité': 'COBOURG',
#     'Totals / Totaux': 21},
#    {'_id': 962,
#     'Year/Année': '1980',
#     'Month/Mois': 'February/février',
#     'Municipality/Municipalité': 'SIMCOE',
#     'Totals / Totaux': 21},
#    {'_id': 963,
#     'Year/Année': '1980',
#     'Month/Mois': 'February/février',
#     'Municipality/Municipalité': 'TRENTON',
#     'Totals / Totaux': 21},
#    {'_id': 964,
#     'Year/Année': '1980',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'KENORA',
#     'Totals / Totaux': 21},
#    {'_id': 965,
#     'Year/Année': '1980',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'LEAMINGTON',
#     'Totals / Totaux': 21},
#    {'_id': 966,
#     'Year/Année': '1980',
#     'Month/Mois': 'July/juillet',
#     'Municipality/Municipalité': 'LEAMINGTON',
#     'Totals / Totaux': 21},
#    {'_id': 967,
#     'Year/Année': '1980',
#     'Month/Mois': 'June/juin',
#     'Municipality/Municipalité': 'SIMCOE',
#     'Totals / Totaux': 21},
#    {'_id': 968,
#     'Year/Année': '1980',
#     'Month/Mois': 'March/mars',
#     'Municipality/Municipalité': 'HAWKESBURY',
#     'Totals / Totaux': 21},
#    {'_id': 969,
#     'Year/Année': '1980',
#     'Month/Mois': 'March/mars',
#     'Municipality/Municipalité': 'TINY T',
#     'Totals / Totaux': 21},
#    {'_id': 970,
#     'Year/Année': '1980',
#     'Month/Mois': 'November/novembre',
#     'Municipality/Municipalité': 'PEMBROKE',
#     'Totals / Totaux': 21},
#    {'_id': 971,
#     'Year/Année': '1980',
#     'Month/Mois': 'November/novembre',
#     'Municipality/Municipalité': 'TIMMINS',
#     'Totals / Totaux': 21},
#    {'_id': 972,
#     'Year/Année': '1980',
#     'Month/Mois': 'October/octobre',
#     'Municipality/Municipalité': 'LEAMINGTON',
#     'Totals / Totaux': 21},
#    {'_id': 973,
#     'Year/Année': '1980',
#     'Month/Mois': 'September/septembre',
#     'Municipality/Municipalité': 'SIMCOE',
#     'Totals / Totaux': 21},
#    {'_id': 974,
#     'Year/Année': '1980',
#     'Month/Mois': 'September/septembre',
#     'Municipality/Municipalité': 'TIMMINS',
#     'Totals / Totaux': 21},
#    {'_id': 975,
#     'Year/Année': '1980',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'LINDSAY',
#     'Totals / Totaux': 22},
#    {'_id': 976,
#     'Year/Année': '1980',
#     'Month/Mois': 'August/août',
#     'Municipality/Municipalité': 'COLLINGWOOD',
#     'Totals / Totaux': 22},
#    {'_id': 977,
#     'Year/Année': '1980',
#     'Month/Mois': 'August/août',
#     'Municipality/Municipalité': 'MILTON',
#     'Totals / Totaux': 22},
#    {'_id': 978,
#     'Year/Année': '1980',
#     'Month/Mois': 'December/décembre',
#     'Municipality/Municipalité': 'DUNNVILLE',
#     'Totals / Totaux': 22},
#    {'_id': 979,
#     'Year/Année': '1980',
#     'Month/Mois': 'February/février',
#     'Municipality/Municipalité': 'WOODSTOCK',
#     'Totals / Totaux': 22},
#    {'_id': 980,
#     'Year/Année': '1980',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'COLLINGWOOD',
#     'Totals / Totaux': 22},
#    {'_id': 981,
#     'Year/Année': '1980',
#     'Month/Mois': 'January/janvier',
#     'Municipality/Municipalité': 'OAKVILLE',
#     'Totals / Totaux': 22},
#    {'_id': 982,
#     'Year/Année': '1980',
#     'Month/Mois': 'July/juillet',
#     'Municipality/Municipalité': 'WOODSTOCK',
#     'Totals / Totaux': 22},
#    {'_id': 983,
#     'Year/Année': '1980',
#     'Month/Mois': 'March/mars',
#     'Municipality/Municipalité': 'BROCKVILLE',
#     'Totals / Totaux': 22},
#    {'_id': 984,
#     'Year/Année': '1980',
#     'Month/Mois': 'March/mars',
#     'Municipality/Municipalité': 'LINDSAY',
#     'Totals / Totaux': 22},
#    {'_id': 985,
#     'Year/Année': '1980',
#     'Month/Mois': 'March/mars',
#     'Municipality/Municipalité': 'PORT COLBORNE',
#     'Totals / Totaux': 22},
#    {'_id': 986,
#     'Year/Année': '1980',
#     'Month/Mois': 'May/mai',
#     'Municipality/Municipalité': 'BARRIE',
#     'Totals / Totaux': 22},
#    {'_id': 987,
#     'Year/Année': '1980',
#     'Month/Mois': 'May/mai',
#     'Municipality/Municipalité': 'LEAMINGTON',
#     'Totals / Totaux': 22},
#    {'_id': 988,
#     'Year/Année': '1980',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'KENORA',
#     'Totals / Totaux': 23},
#    {'_id': 989,
#     'Year/Année': '1980',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'ORILLIA',
#     'Totals / Totaux': 23},
#    {'_id': 990,
#     'Year/Année': '1980',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'SIMCOE',
#     'Totals / Totaux': 23},
#    {'_id': 991,
#     'Year/Année': '1980',
#     'Month/Mois': 'April/avril',
#     'Municipality/Municipalité': 'TIMMINS',
#     'Totals / Totaux': 23},
#    {'_id': 992,
#     'Year/Année': '1980',
#     'Month/Mois': 'August/août',
#     'Municipality/Municipalité': 'SIMCOE',
#     'Totals / Totaux': 23},
#    {'_id': 993,
#     'Year/Année': '1980',
#     'Month/Mois': 'February/février',
#     'Municipality/Municipalité': 'LINDSAY',
#     'Totals / Totaux': 23},
#    {'_id': 994,
#     'Year/Année': '1980',
#     'Month/Mois': 'February/février',
#     'Municipality/Municipalité': 'OWEN SOUND',
#     'Totals / Totaux': 23},
#    {'_id': 995,
#     'Year/Année': '1980',
#     'Month/Mois': 'June/juin',
#     'Municipality/Municipalité': 'BROCKVILLE',
#     'Totals / Totaux': 23},
#    {'_id': 996,
#     'Year/Année': '1980',
#     'Month/Mois': 'June/juin',
#     'Municipality/Municipalité': 'STRATFORD',
#     'Totals / Totaux': 23},
#    {'_id': 997,
#     'Year/Année': '1980',
#     'Month/Mois': 'November/novembre',
#     'Municipality/Municipalité': 'LINDSAY',
#     'Totals / Totaux': 23},
#    {'_id': 998,
#     'Year/Année': '1980',
#     'Month/Mois': 'November/novembre',
#     'Municipality/Municipalité': 'SIMCOE',
#     'Totals / Totaux': 23},
#    {'_id': 999,
#     'Year/Année': '1980',
#     'Month/Mois': 'October/octobre',
#     'Municipality/Municipalité': 'LINDSAY',
#     'Totals / Totaux': 23},
#    {'_id': 1000,
#     'Year/Année': '1980',
#     'Month/Mois': 'September/septembre',
#     'Municipality/Municipalité': 'OWEN SOUND',
#     'Totals / Totaux': 23},
#    ...],
#   'fields': [{'id': '_id', 'type': 'int'},
#    {'id': 'Year/Année', 'type': 'text'},
#    {'id': 'Month/Mois',
#     'type': 'text',
#     'info': {'notes': '', 'type_override': '', 'label': ''}},
#    {'id': 'Municipality/Municipalité', 'type': 'text'},
#    {'id': 'Totals / Totaux',
#     'type': 'numeric',
#     'info': {'notes': '', 'type_override': 'numeric', 'label': ''}}],
#   '_links': {'start': '/api/3/action/datastore_search?resource_id=2925c1ea-8313-4e9b-bdea-344e521d2298&limit=100000',
#    'next': '/api/3/action/datastore_search?resource_id=2925c1ea-8313-4e9b-bdea-344e521d2298&limit=100000&offset=100000'},
#   'total': 68053,
#   'total_was_estimated': False}}

# %% [markdown]
# This dataset is of the death registrations in Ontario by location. It has columns for year, month, location and number of deaths for that month and location

# %%
data = response.json()
data.keys()
# Out:
# dict_keys(['help', 'success', 'result'])

# %%
deaths = pd.DataFrame(data['result']['records'])
deaths
# Out:
#          _id Year/Année         Month/Mois Municipality/Municipalité  \
# 0          1       1940        August/août                   TORONTO
# 1          2       1940    October/octobre                   TORONTO
# 2          3       1942  November/novembre                   TORONTO
# 3          4       1944        April/avril                   TORONTO
# 4          5       1944    January/janvier                   TORONTO
# ...      ...        ...                ...                       ...
# 68048  68049       2023  December/décembre                    WHITBY
# 68049  68050       2023  December/décembre    WHITCHURCH-STOUFFVILLE
# 68050  68051       2023  December/décembre                   WINDSOR
# 68051  68052       2023  December/décembre                 WOODSTOCK
# 68052  68053       2023  December/décembre                  WOOLWICH
#
#        Totals / Totaux
# 0                    6
# 1                    6
# 2                    6
# 3                    6
# 4                    6
# ...                ...
# 68048               37
# 68049               16
# 68050              269
# 68051               50
# 68052                9
#
# [68053 rows x 5 columns]

# %% [markdown]
# # Data Cleaning and Feature Engineering

# %%
# Data Cleaning
deaths['Month'] = deaths['Month/Mois'].apply(lambda x: x.split('/')[0])
deaths.rename(columns={'Year/Année': 'Year'}, inplace=True)
deaths['Year'] = deaths['Year'].astype(int)

# We want information of deaths for Ontario by year
deaths_by_year = deaths.groupby('Year').agg(Total=('Totals / Totaux', 'sum'))
deaths_by_year.reset_index(inplace=True)

# We calculate five year rolling data and start the rolling calculation from 1944 since 1943 and 1942 data is missing
deaths_by_year['Five Year Rolling Average'] = deaths_by_year[deaths_by_year['Year'] > 1944]['Total'].rolling(5).mean().round(2)

# We also calculate total deaths since 1940
deaths_by_year['Total Deaths Since 1940'] = deaths_by_year['Total'].cumsum()

# For each year we also get the month with the most deaths and the number of these deaths
# This is a slightly more involved process
deaths_by_year_and_month = deaths.groupby(['Year', 'Month']).agg(Total=('Totals / Totaux', 'sum'))
deaths_by_year_and_month.reset_index(inplace=True)

deaths_by_year_and_highest_month = deaths_by_year_and_month.loc[deaths_by_year_and_month.groupby('Year')['Total'].idxmax()]
deaths_by_year_and_highest_month.reset_index(inplace=True)
deaths_by_year_and_highest_month.drop('index', inplace=True, axis=1)

deaths_by_year_and_highest_month.rename(columns={'Total': 'Number of Deaths in Highest Month', 'Month': 'Month with most Deaths'}, inplace=True)

deaths_by_year = pd.merge(deaths_by_year, deaths_by_year_and_highest_month, on='Year')

deaths_by_year
# Out:
#     Year   Total  Five Year Rolling Average  Total Deaths Since 1940  \
# 0   1940      12                        NaN                       12
# 1   1942       6                        NaN                       18
# 2   1944      12                        NaN                       30
# 3   1945      13                        NaN                       43
# 4   1946      22                        NaN                       65
# ..   ...     ...                        ...                      ...
# 77  2019  103463                    97289.0                  3046365
# 78  2020  111574                   101428.4                  3157939
# 79  2021  113469                   105503.8                  3271408
# 80  2022  121697                   110305.2                  3393105
# 81  2023  111218                   112284.2                  3504323
#
#    Month with most Deaths  Number of Deaths in Highest Month
# 0                  August                                  6
# 1                November                                  6
# 2                   April                                  6
# 3                 January                                  7
# 4               September                                  9
# ..                    ...                                ...
# 77                January                               9633
# 78                  April                              10815
# 79                January                              11247
# 80                January                              12699
# 81                January                              10658
#
# [82 rows x 6 columns]

# %% [markdown]
# # Create Database Engine and Connection
# ## Login with York Credentials

# %%
york_username = "dali96"
# Dictionary - params to set up the DB Engine
mmai_db_secret = {
    "database": "dali96_db",
    "drivername": "mssql+pyodbc",
    "host": "mmai2024-ms-sql-server.c1oick8a8ywa.ca-central-1.rds.amazonaws.com",
    "port": "1433",
    "username": york_username,
    "password": "2024!Schulich",
    "driver": "ODBC Driver 18 for SQL Server",
    "trust_cert": "yes"
}


# Function to create the DB engine - DO NOT TOUCH
def create_db_engine(db_config):
    connection_url = sa.engine.URL.create(
        drivername=db_config.get("drivername"),
        username=db_config.get("username"),
        password=db_config.get("password"),
        host=db_config.get("host"),
        port=db_config.get("port"),
        database=db_config.get("database"),
        query={
            "driver": db_config.get("driver"),
            "TrustServerCertificate": db_config.get("trust_cert")
        }
    )
    return sa.create_engine(connection_url)


# Initialize the MySql Engine using SQL Alchemy
mssql_engine = create_db_engine(mmai_db_secret)

# %% [markdown]
# # Ingest Data into our Database

# %%
deaths_by_year.to_sql(
    name   = 'ontario_deaths',
    con    = mssql_engine,
    schema = 'uploads',
    if_exists = 'replace',
    index  = False,
    dtype  = {
        'year'      : sa.types.DATE,
        'total' : sa.types.INTEGER,
        'five_year_rolling_average' : sa.types.DECIMAL(10,2),
        'total_deaths_since_1940': sa.types.INTEGER,
        'month_with_most_deaths': sa.types.String,
        'number_of_deaths_in_month': sa.types.INTEGER
    },
    method = 'multi'
)
# Out:
# 82
